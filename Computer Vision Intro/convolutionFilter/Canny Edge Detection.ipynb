# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

image = cv2.imread('images/brain_MR.jpg')

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# # Implement Canny Edge Detection

# %%
# Convert it to grayscale for processing
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray)

# %%
# Canny using "wide" and "tight threshold
wide = cv2.Canny(gray, 30, 100)
tight = cv2.Canny(gray, 200, 240)

#display
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
ax1.set_title('wide')
ax1.imshow(wide, cmap='gray')

ax2.set_title('tight')
ax2.imshow(tight, cmap='gray')

# %% [markdown]
# # Find the edges of this flower

# %%
image = cv2.imread('images/sunflower.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

#TODO
l1 = 210
l2 = 240
edge1 = cv2.Canny(gray, l1, l2)
############
lower = 0
upper = 50
edges = cv2.Canny(gray, lower, upper)

f, (a1, a2)= plt.subplots(1, 2, figsize=(20, 10))

a1.set_title('fig1')
a1.imshow(edges, cmap='gray')

a2.set_title('fig2')
a2.imshow(edge1, cmap='gray')
